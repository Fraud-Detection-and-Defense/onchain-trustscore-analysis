# %% [markdown]
# ## Gitcoin Grants #14 Trust & DeSoc Scores (🤖,💚)
#
# # Part 5: Labeled Datasets for Community
#
# This notebook produces labeled datasets for sharing with community members.

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
from settings import PATHS
from utils.classifiers import CLASSIFIERS

# %% [markdown]
# # 1/ Ingest GR 14 data
#
# Load the "clean" dataset with a number of indicators derived from onchain metrics for additional processing.

# %%
df = pd.read_pickle(PATHS['outdata'])
classified_wallets = pd.concat([
    df.apply(c.func, axis=1).rename(c.name)
    for c in CLASSIFIERS
], axis=1)
df = df.join(classified_wallets)
df.head(1)
# Out:
#                                             isSquelched  trustscore  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9          0.0        1.15
#
#                                               qfScore  numDonations  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9  84.602763            27
#
#                                             numGrants  sumUSD  numTokens  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9         26  278.75          1
#
#                                            setTokens  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9   {'DAI'}
#
#                                                                                     setGrants  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9  {258, 3591, 5511, 12, 4493, 5007, 1297, 5013, ...
#
#                                            binTrustscore  ... poap_art_poaps  \
# address                                                   ...
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9   (1.0, 1.25]  ...          False
#
#                                             dao_voter  snapshot_user  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9       True           True
#
#                                             ens_voter gitcoin_voter  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9      False         False
#
#                                            optimism_voter  arbitrum_voter  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9          False           False
#
#                                             lens_active lens_followers  \
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9         True          False
#
#                                             proof_of_humanity
# address
# 0x00000000000cd56832ce5dfbcbff02e7ec639bc9              False
#
# [1 rows x 41 columns]

# %% [markdown]
# # 2/ Prepare outfiles to share with community

# %%
grant_features = ['numDonations', 'sumUSD', 'setGrants']
sybil_indicators = ['isSquelched', 'burner', 'trustscore']

# %%
outpath = "../private_data/community/gr14_user_transactions.csv"
df[grant_features].to_csv(outpath)

# %% [markdown]
# # 3/ Compare results with community models

# %%
infile = '../private_data/community/220905_community_screening.csv'

with open(infile) as f:
    lines = [line.replace("\n","").lower() for line in f]

community_df = (pd
                .DataFrame(lines[1:], columns=['address'])
                .set_index('address')
                .join(df[grant_features + sybil_indicators]))
community_df['low_trustscore'] = community_df['trustscore'] == 0.5
community_df
# Out:
#                                             numDonations     sumUSD  \
# address
# 0x1502a19729df969ced987961830a356f59a7f1c0          16.0  15.750000
# 0xed57d041d6ce7601af2c635976ce3f30a65eadff          16.0  15.750000
# 0x930df074acf694238bdf6e1c947e1c5442d5f019          15.0  14.916477
# 0x1e6c3c2054ec6027b653715be963fed04b836501          15.0  14.835828
# 0xb4d0157329ffec6d327cd145688f280a4aa1c974          15.0  14.835828
# ...                                                  ...        ...
# 0xfefe763f27a3ebb9d9ceafe94a6d9ad2358a2b99           1.0   1.001132
# 0xff6f05d27afcc044b08a0c70d596f749d91d6652           1.0   1.014594
# 0xffc26c83b50f62ebd4e5b0c44915d4bf36cd0584           5.0  63.000000
# 0xffd3f0393f7bb8daa930668a51b885d48476abec           1.0   1.030818
# 0xffe45f05165cde61ef96c72066641b1a87656af4          13.0  15.150000
#
#                                                                                     setGrants  \
# address
# 0x1502a19729df969ced987961830a356f59a7f1c0  {5857, 6115, 37, 3591, 5288, 5688, 5995, 12, 5...
# 0xed57d041d6ce7601af2c635976ce3f30a65eadff  {5857, 6115, 37, 3591, 5288, 5688, 5995, 12, 5...
# 0x930df074acf694238bdf6e1c947e1c5442d5f019  {6115, 37, 3591, 5288, 5688, 5995, 12, 5007, 4...
# 0x1e6c3c2054ec6027b653715be963fed04b836501  {6115, 37, 3591, 5288, 5688, 5995, 12, 5007, 4...
# 0xb4d0157329ffec6d327cd145688f280a4aa1c974  {6115, 37, 3591, 5288, 5688, 5995, 12, 5007, 4...
# ...                                                                                       ...
# 0xfefe763f27a3ebb9d9ceafe94a6d9ad2358a2b99                                             {3591}
# 0xff6f05d27afcc044b08a0c70d596f749d91d6652                                             {3591}
# 0xffc26c83b50f62ebd4e5b0c44915d4bf36cd0584                         {37, 3591, 12, 2198, 5688}
# 0xffd3f0393f7bb8daa930668a51b885d48476abec                                             {3591}
# 0xffe45f05165cde61ef96c72066641b1a87656af4  {6115, 37, 3591, 5288, 12, 5007, 1620, 5940, 2...
#
#                                             isSquelched burner  trustscore  \
# address
# 0x1502a19729df969ced987961830a356f59a7f1c0          1.0  False         0.5
# 0xed57d041d6ce7601af2c635976ce3f30a65eadff          1.0   True         0.5
# 0x930df074acf694238bdf6e1c947e1c5442d5f019          0.0  False         0.5
# 0x1e6c3c2054ec6027b653715be963fed04b836501          0.0  False         0.5
# 0xb4d0157329ffec6d327cd145688f280a4aa1c974          0.0  False         0.5
# ...                                                 ...    ...         ...
# 0xfefe763f27a3ebb9d9ceafe94a6d9ad2358a2b99          1.0   True         0.5
# 0xff6f05d27afcc044b08a0c70d596f749d91d6652          1.0   True         0.5
# 0xffc26c83b50f62ebd4e5b0c44915d4bf36cd0584          0.0  False         0.5
# 0xffd3f0393f7bb8daa930668a51b885d48476abec          1.0  False         0.5
# 0xffe45f05165cde61ef96c72066641b1a87656af4          1.0  False         0.5
#
#                                             low_trustscore
# address
# 0x1502a19729df969ced987961830a356f59a7f1c0            True
# 0xed57d041d6ce7601af2c635976ce3f30a65eadff            True
# 0x930df074acf694238bdf6e1c947e1c5442d5f019            True
# 0x1e6c3c2054ec6027b653715be963fed04b836501            True
# 0xb4d0157329ffec6d327cd145688f280a4aa1c974            True
# ...                                                    ...
# 0xfefe763f27a3ebb9d9ceafe94a6d9ad2358a2b99            True
# 0xff6f05d27afcc044b08a0c70d596f749d91d6652            True
# 0xffc26c83b50f62ebd4e5b0c44915d4bf36cd0584            True
# 0xffd3f0393f7bb8daa930668a51b885d48476abec            True
# 0xffe45f05165cde61ef96c72066641b1a87656af4            True
#
# [2612 rows x 7 columns]

# %%
community_df.iloc[:,-3:].mean()
# Out:
# burner            0.320552
# trustscore        0.614010
# low_trustscore    0.810107
# dtype: float64

# %%
outfile = '../private_data/community/220905_community_screening_results.csv'
community_df.to_csv(outfile)
